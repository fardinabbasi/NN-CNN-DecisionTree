# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#-Q6-" data-toc-modified-id="-Q6--1"><span class="toc-item-num">1&nbsp;&nbsp;</span> Q6 </a></span><ul class="toc-item"><li><span><a href="#-Part-A-&amp;-B-" data-toc-modified-id="-Part-A-&amp;-B--1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span> Part A &amp; B </a></span></li><li><span><a href="#-Part-C-" data-toc-modified-id="-Part-C--1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span> Part C </a></span></li><li><span><a href="#-Part-D-" data-toc-modified-id="-Part-D--1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span> Part D </a></span></li><li><span><a href="#-Part-F-" data-toc-modified-id="-Part-F--1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span> Part F </a></span></li></ul></li><li><span><a href="#-Q7-" data-toc-modified-id="-Q7--2"><span class="toc-item-num">2&nbsp;&nbsp;</span> Q7 </a></span><ul class="toc-item"><li><span><a href="#-Part-A-" data-toc-modified-id="-Part-A--2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span> Part A </a></span></li><li><span><a href="#-Part-B-" data-toc-modified-id="-Part-B--2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span> Part B </a></span></li><li><span><a href="#-Part-C-" data-toc-modified-id="-Part-C--2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span> Part C </a></span></li></ul></li><li><span><a href="#-Q8-" data-toc-modified-id="-Q8--3"><span class="toc-item-num">3&nbsp;&nbsp;</span> Q8 </a></span><ul class="toc-item"><li><span><a href="#-Part-A-" data-toc-modified-id="-Part-A--3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span> Part A </a></span></li><li><span><a href="#-Part-B-" data-toc-modified-id="-Part-B--3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span> Part B </a></span></li><li><span><a href="#-Part-C-&amp;-D-" data-toc-modified-id="-Part-C-&amp;-D--3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span> Part C &amp; D </a></span><ul class="toc-item"><li><span><a href="#-SGD-" data-toc-modified-id="-SGD--3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span> SGD </a></span></li><li><span><a href="#-Adam-" data-toc-modified-id="-Adam--3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span> Adam </a></span></li><li><span><a href="#-rmsprop-" data-toc-modified-id="-rmsprop--3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span> rmsprop </a></span></li></ul></li></ul></li><li><span><a href="#-Q9-" data-toc-modified-id="-Q9--4"><span class="toc-item-num">4&nbsp;&nbsp;</span> Q9 </a></span><ul class="toc-item"><li><span><a href="#-Part-A-" data-toc-modified-id="-Part-A--4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span> Part A </a></span></li><li><span><a href="#-Part-B-" data-toc-modified-id="-Part-B--4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span> Part B </a></span></li><li><span><a href="#-Part-D-" data-toc-modified-id="-Part-D--4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span> Part D </a></span></li></ul></li></ul></div>

# %% [markdown]
# <h1> Q6 </h1>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

# %%
PATH = "D:\دانشگاه تهران\ترم6\ML\HW\ECG.csv"
ECG = pd.read_csv(PATH)
ECG.drop('Unnamed: 0',axis=1, inplace=True)
ECG.head()
# Out:
#   label  feat1       feat2       feat3      feat4       feat5       feat6  \
# 0     O      5  661.190476  658.333333  55.278736  106.962730  111.113889
# 1     O      5  661.666667  658.333333  56.579873  108.407273  112.510209
# 2     O      8  661.904762  660.000000  58.758004  112.796617  117.091412
# 3     O      7  660.952381  663.333333  59.029597  113.649634  117.981601
# 4     O      5  660.476191  663.333333  55.759820  107.623910  111.732026
#
#    feat7     feat8  feat9  ...   feat160  feat161   feat162   feat163  \
# 0     13  0.928571  0.041  ...  0.165551    0.196  0.321645  0.074160
# 1     13  0.928571  0.150  ...  0.190431    0.196  0.362420  0.085271
# 2     13  0.928571  0.041  ...  0.094497    0.316  0.376645  0.042448
# 3     13  0.928571  0.041  ...  0.157149    0.284  0.419043  0.070674
# 4     13  0.928571  0.041  ...  0.162662    0.204  0.354123  0.072988
#
#     feat164   feat165   feat166   feat167  feat168  feat169
# ...

# %% [markdown]
# <h2> Part A & B </h2>

# %%
print(ECG['label'].value_counts())

plt.figure()
ECG['label'].value_counts().plot(kind='bar',color='g')
plt.show()
# Out:
# N    5992
# O    3151
# A     923
# ~     187
# Name: label, dtype: int64

# %% [markdown]
# <h2> Part C </h2>

# %%
X = ECG.drop('label', axis = 1, inplace = False)
Y = ECG['label']

X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
clf = MLPClassifier(hidden_layer_sizes=(128,64,32,16), activation='relu', solver='sgd', max_iter=1000, random_state=42)
clf.fit(X_train, Y_train)
y_pred = clf.predict(X_test)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print(classification_report(Y_test, y_pred,zero_division=0))
ConfusionMatrixDisplay(confusion_matrix(Y_test,y_pred),display_labels=['A','N','O','~']).plot();
# Out:
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00        98
#            N       0.58      1.00      0.73       590
#            O       0.00      0.00      0.00       321
#            ~       0.00      0.00      0.00        17
#
#     accuracy                           0.58      1026
#    macro avg       0.14      0.25      0.18      1026
# weighted avg       0.33      0.58      0.42      1026

# %% [markdown]
# <h2> Part D </h2>

# %%
X_train_scaled = StandardScaler().fit_transform(X_train)
X_test_scaled = StandardScaler().fit_transform(X_test)

clf = MLPClassifier(hidden_layer_sizes=(128,64,32,16), activation='relu', solver='sgd', max_iter=1000, random_state=42)
clf.fit(X_train_scaled, Y_train)
y_pred_scaled = clf.predict(X_test_scaled)

# %%
print(classification_report(Y_test, y_pred_scaled,zero_division=0))
ConfusionMatrixDisplay(confusion_matrix(Y_test,y_pred_scaled),display_labels=['A','N','O','~']).plot();
# Out:
#               precision    recall  f1-score   support
#
#            A       0.89      0.85      0.87        98
#            N       0.86      0.86      0.86       590
#            O       0.74      0.75      0.75       321
#            ~       0.56      0.59      0.57        17
#
#     accuracy                           0.82      1026
#    macro avg       0.76      0.76      0.76      1026
# weighted avg       0.82      0.82      0.82      1026

# %% [markdown]
# <h2> Part F </h2>

# %%
ECG_new = ECG.drop(ECG[ECG['label'] == '~'].index, inplace=False)
ECG_new['label'].replace(['A','O'],'Other', inplace=True)

X_new = ECG_new.drop('label',axis=1)
Y_new = ECG_new['label']
X_new_train, X_new_test, Y_new_train, Y_new_test = train_test_split(X_new, Y_new, test_size=0.1, random_state=42)

X_new_train_scaled = StandardScaler().fit_transform(X_new_train)
X_new_test_scaled = StandardScaler().fit_transform(X_new_test)

clf = MLPClassifier(hidden_layer_sizes=(64,32,16), activation='relu', solver='sgd', max_iter=1000, random_state=42)
clf.fit(X_new_train_scaled,Y_new_train)
y_new_pred = clf.predict(X_new_test_scaled)

# %%
print(classification_report(Y_new_test, y_new_pred,zero_division=0))
ConfusionMatrixDisplay(confusion_matrix(Y_new_test,y_new_pred),display_labels=['N','Other']).plot();
# Out:
#               precision    recall  f1-score   support
#
#            N       0.89      0.93      0.91       608
#        Other       0.89      0.82      0.86       399
#
#     accuracy                           0.89      1007
#    macro avg       0.89      0.88      0.88      1007
# weighted avg       0.89      0.89      0.89      1007

# %% [markdown]
# <h1> Q7 </h1>

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
def circular_points(center,radius,n):

    r = np.random.random(n)*(radius[1]-radius[0]) + radius[0]
    alpha= 2 * np.pi * np.random.random(n)
    points = np.vstack((r*np.cos(alpha)+center[0], r*np.sin(alpha)+center[1])).T
    return points

class Adaline:
    def __init__(self, input_size):
        self.weights = np.random.randn(input_size + 1)
        self.z = 0
        
    def predict(self, inputs):
        X = np.insert(inputs, 0, 1)
        self.z = np.dot(self.weights, X)
        return self.activate(self.z)
    
    def train(self, input_vector, target, learning_rate=0.01):
        X = np.insert(input_vector, 0, 1)
        self.weights += learning_rate * (target-self.z)* X
        
    def activate(self, x):
        return 1 if x >= 0 else 0

class Madaline:
    def __init__(self, input_size, hidden_size, learning_rate):
        self.adalines = [Adaline(input_size) for _ in range(hidden_size)]
        self.learning_rate = learning_rate
        
    def train(self, input_vectors, targets, epochs=100):
        for _ in range(epochs):
            for input_vector, target in zip(input_vectors, targets):
                if(self.predict(input_vector)!=target):
                    zs = np.array([np.abs(adaline.z) for adaline in self.adalines])
                    if(target):
                        closest_to0_idx = np.argmin(zs)
                        self.adalines[closest_to0_idx].train(input_vector, 1, self.learning_rate)
                    else:
                        positive_net_idx = np.where(zs>0)
                        for i in positive_net_idx[0]:
                            self.adalines[i].train(input_vector, -1, self.learning_rate)

    def predict(self, input_vector):
        vec = np.array([adaline.predict(input_vector) for adaline in self.adalines])
        return 1 if (np.any(vec)) else 0 # simple logical OR function (MRI)

# %% [markdown]
# <h2> Part A </h2>

# %%
size = 100
circle1 = circular_points([0,0],[0,1],size)
circle2 = circular_points([0,0],[1.3,1.6],size)
plt.figure()
plt.scatter(circle1[:,0],circle1[:,1],c='b',marker='o')
plt.scatter(circle2[:,0],circle2[:,1],c='g',marker='x')
plt.legend(['Class 1','Class 2'])
plt.show()

# %% [markdown]
# <h2> Part B </h2>

# %%
X = np.vstack((circle1,circle2))
Y = np.vstack((np.zeros((size,1)),np.ones((size,1))))
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model1 = Madaline(input_size=2, hidden_size=3, learning_rate=0.05)
model1.train(X_train, y_train)

fig, ax = plt.subplots()
x1 = np.linspace(-2, 2, 100)
for ad in model1.adalines:
    x2 = (ad.weights[1]*x1-ad.weights[0])/ad.weights[2]
    # Plot the lines
    ax.plot(x1, x2, c='black')

ax.scatter(X_test[:,0],X_test[:,1], c=np.where(y_test[:,0]==1, "g", "r"))
ax.set_ylim(-2,2);

# %%
y_pred = np.array([model1.predict(x) for x in X_test])

print(classification_report(y_test,y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot();
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        21
#          1.0       1.00      0.89      0.94        19
#
#     accuracy                           0.95        40
#    macro avg       0.96      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40

# %% [markdown]
# <h2> Part C </h2>

# %%
model2 = Madaline(input_size=2, hidden_size=6, learning_rate=0.01)
model2.train(X_train, y_train)

fig, ax = plt.subplots()
x1 = np.linspace(-2, 2, 100)
for ad in model2.adalines:
    x2 = (ad.weights[1]*x1-ad.weights[0])/ad.weights[2]
    # Plot the lines
    ax.plot(x1, x2, c='black')

ax.scatter(X_test[:,0],X_test[:,1], c=np.where(y_test[:,0]==1, "g", "r"))
ax.set_ylim(-2,2);

# %%
y_pred = np.array([model2.predict(x) for x in X_test])

print(classification_report(y_test,y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot();
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        21
#          1.0       1.00      0.95      0.97        19
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40

# %% [markdown]
# <h1> Q8 </h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# <h2> Part A </h2>

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

for i in np.random.randint(0,len(X_train),5):
    plt.figure()
    plt.imshow(X_train[i])
    plt.axis('off')
    plt.show()

# %% [markdown]
# <h2> Part B </h2>

# %%
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

x_train, x_valid, y_train, y_valid = train_test_split(X_train, Y_train, test_size=0.8, random_state=42)

# %% [markdown]
# <h2> Part C & D </h2>

# %%
cnn = keras.Sequential(
    [
        layers.Conv2D(32, (3, 3), activation="relu",  input_shape=x_train.shape[1:]),
        layers.Conv2D(32, (3, 3), activation="relu"),
        layers.Conv2D(32, (3, 3), activation="relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Conv2D(64, (3, 3), activation="relu"),
        layers.Conv2D(64, (3, 3), activation="relu"),
        layers.Conv2D(64, (3, 3), activation="relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(512, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax"),
    ]
)

cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 64)          36928
# ...

# %% [markdown]
# <h3> SGD </h3>

# %%
cnn.compile(optimizer="sgd",loss="categorical_crossentropy" ,metrics=["Precision"])

history = cnn.fit(x_train, y_train, epochs=10, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 313/313 [==============================] - 34s 110ms/step - loss: 2.2995 - precision: 0.0000e+00 - val_loss: 2.2897 - val_precision: 0.0000e+00
# Epoch 2/10
# 313/313 [==============================] - 34s 109ms/step - loss: 2.2439 - precision: 0.6667 - val_loss: 2.1755 - val_precision: 0.0000e+00
# Epoch 3/10
# 313/313 [==============================] - 34s 109ms/step - loss: 2.1692 - precision: 0.3977 - val_loss: 2.1735 - val_precision: 0.5516
# Epoch 4/10
# 313/313 [==============================] - 35s 110ms/step - loss: 2.1200 - precision: 0.4138 - val_loss: 2.0517 - val_precision: 0.7207
# Epoch 5/10
# 313/313 [==============================] - 34s 109ms/step - loss: 2.0882 - precision: 0.3929 - val_loss: 2.1719 - val_precision: 1.0000
# Epoch 6/10
# 313/313 [==============================] - 34s 109ms/step - loss: 2.0506 - precision: 0.5058 - val_loss: 2.0652 - val_precision: 0.8182
# Epoch 7/10
# ...

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['precision'], label='Training Precision')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.title('SGD')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epoch')
plt.title('SGD')
plt.ylabel('Metric')
plt.legend()
plt.show()

# %%
y_pred_sgd = np.argmax(cnn.predict(X_test), axis=1)

print(classification_report(np.argmax(Y_test, axis=1), y_pred_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.43      0.42      1000
#            1       0.36      0.63      0.46      1000
#            2       0.37      0.07      0.11      1000
#            3       0.30      0.06      0.09      1000
#            4       0.19      0.04      0.07      1000
#            5       0.35      0.24      0.29      1000
#            6       0.28      0.69      0.40      1000
#            7       0.29      0.41      0.34      1000
#            8       0.37      0.41      0.39      1000
#            9       0.38      0.39      0.39      1000
#
#     accuracy                           0.34     10000
#    macro avg       0.33      0.34      0.30     10000
# weighted avg       0.33      0.34      0.30     10000

# %% [markdown]
# <h3> Adam </h3>

# %%
cnn.compile(optimizer="adam",loss="mean_squared_error" ,metrics=["Precision"])
history = cnn.fit(x_train, y_train, epochs=10, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 313/313 [==============================] - 36s 116ms/step - loss: 0.0805 - precision: 0.5530 - val_loss: 0.0776 - val_precision: 0.6343
# Epoch 2/10
# 313/313 [==============================] - 35s 112ms/step - loss: 0.0760 - precision: 0.5868 - val_loss: 0.0712 - val_precision: 0.6866
# Epoch 3/10
# 313/313 [==============================] - 38s 120ms/step - loss: 0.0719 - precision: 0.6376 - val_loss: 0.0676 - val_precision: 0.6670
# Epoch 4/10
# 313/313 [==============================] - 39s 125ms/step - loss: 0.0677 - precision: 0.6669 - val_loss: 0.0643 - val_precision: 0.6749
# Epoch 5/10
# 313/313 [==============================] - 39s 124ms/step - loss: 0.0652 - precision: 0.6957 - val_loss: 0.0638 - val_precision: 0.6711
# Epoch 6/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0627 - precision: 0.7067 - val_loss: 0.0623 - val_precision: 0.6904
# Epoch 7/10
# ...

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['precision'], label='Training Precision')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.title('Adam')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epoch')
plt.title('Adam')
plt.ylabel('Metric')
plt.legend()
plt.show()

# %%
y_pred_adam = np.argmax(cnn.predict(X_test), axis=1)

print(classification_report(np.argmax(Y_test, axis=1), y_pred_adam))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.59      0.57      1000
#            1       0.66      0.79      0.72      1000
#            2       0.42      0.43      0.42      1000
#            3       0.38      0.31      0.34      1000
#            4       0.53      0.27      0.36      1000
#            5       0.46      0.58      0.51      1000
#            6       0.64      0.69      0.67      1000
#            7       0.65      0.60      0.63      1000
#            8       0.61      0.73      0.67      1000
#            9       0.66      0.61      0.63      1000
#
#     accuracy                           0.56     10000
#    macro avg       0.56      0.56      0.55     10000
# weighted avg       0.56      0.56      0.55     10000

# %% [markdown]
# <h3> rmsprop </h3>

# %%
cnn.compile(optimizer="rmsprop",loss="mean_squared_error" ,metrics=["Precision"])
history = cnn.fit(x_train, y_train, epochs=10, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 313/313 [==============================] - 36s 115ms/step - loss: 0.0530 - precision: 0.7549 - val_loss: 0.0614 - val_precision: 0.6474
# Epoch 2/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0506 - precision: 0.7609 - val_loss: 0.0550 - val_precision: 0.7081
# Epoch 3/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0500 - precision: 0.7609 - val_loss: 0.0560 - val_precision: 0.7177
# Epoch 4/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0485 - precision: 0.7737 - val_loss: 0.0560 - val_precision: 0.7044
# Epoch 5/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0475 - precision: 0.7702 - val_loss: 0.0549 - val_precision: 0.7111
# Epoch 6/10
# 313/313 [==============================] - 35s 113ms/step - loss: 0.0463 - precision: 0.7738 - val_loss: 0.0554 - val_precision: 0.7174
# Epoch 7/10
# ...

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['precision'], label='Training Precision')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.title('rmsprop')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epoch')
plt.title('rmsprop')
plt.ylabel('Metric')
plt.legend()
plt.show()

# %%
y_pred_rmsprop = np.argmax(cnn.predict(X_test), axis=1)

print(classification_report(np.argmax(Y_test, axis=1), y_pred_rmsprop))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.61      1000
#            1       0.71      0.78      0.74      1000
#            2       0.54      0.40      0.46      1000
#            3       0.43      0.34      0.38      1000
#            4       0.43      0.57      0.49      1000
#            5       0.54      0.55      0.54      1000
#            6       0.60      0.76      0.67      1000
#            7       0.69      0.60      0.64      1000
#            8       0.76      0.65      0.70      1000
#            9       0.61      0.73      0.66      1000
#
#     accuracy                           0.59     10000
#    macro avg       0.60      0.59      0.59     10000
# weighted avg       0.60      0.59      0.59     10000

# %% [markdown]
# <h1> Q9 </h1>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import precision_score
from sklearn.preprocessing import normalize

# %% [markdown]
# <h2> Part A </h2>

# %%
PATH = "D:\دانشگاه تهران\ترم6\ML\HW\Diabetes.csv"
df = pd.read_csv(PATH)
print(df.head())
X = df.drop('label', axis = 1, inplace = False)
Y = df['label']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# Out:
#    pregnant  glucose  BP  skin  insulin   BMI  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train,Y_train)
y_pred_test = clf.predict(X_test)
y_pred_train = clf.predict(X_train)

# %%
print("Percision for test data = "+str(round(precision_score(Y_test,y_pred_test)*100,3))+"%")
print("Percision for train data = "+str(precision_score(Y_train,y_pred_train)*100)+"%")
# Out:
# Percision for test data = 60.92%
# Percision for train data = 100.0%

# %% [markdown]
# <h2> Part B </h2>

# %%
fig = plt.figure(figsize=(50,50))
_ = plot_tree(clf, 
                   feature_names=X.columns,  
                   class_names=['0','1'],
                   filled=True)

# %% [markdown]
# <h2> Part D </h2>

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=2)
clf.fit(X_train,Y_train)
y_pred_test = clf.predict(X_test)
y_pred_train = clf.predict(X_train)

# %%
print("Percision for test data = "+str(round(precision_score(Y_test,y_pred_test)*100,3))+"%")
print("Percision for train data = "+str(round(precision_score(Y_train,y_pred_train)*100,3))+"%")
# Out:
# Percision for test data = 69.231%
# Percision for train data = 85.542%

# %%
fig = plt.figure(figsize=(10,10))
_ = plot_tree(clf, 
                   feature_names=X.columns,  
                   class_names=['0','1'],proportion=True,
                   filled=True)
